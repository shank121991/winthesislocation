# %%
import pysal.esda.mapclassify as mapclassify
import pandas as pd
import os
from mapboxgl.utils import *
from mapboxgl.viz import *

# %%
df = pd.read_csv('/home/shashank/Downloads/Geolife Trajectories 1.3/Data/000/Trajectory/20081023025304.plt', skiprows=6, header = None).round(3)
df.columns = ['Latitude', 'Longitude', '0', 'Altitude', 'NumDays', 'Date', 'Time']
df.head(5)
# Out:
#    Latitude  Longitude  0  Altitude   NumDays        Date      Time
# 0    39.985    116.318  0       492  39744.12  2008-10-23  02:53:04
# 1    39.985    116.318  0       492  39744.12  2008-10-23  02:53:10
# 2    39.985    116.318  0       492  39744.12  2008-10-23  02:53:15
# 3    39.985    116.318  0       492  39744.12  2008-10-23  02:53:20
# 4    39.985    116.318  0       492  39744.12  2008-10-23  02:53:25

# %%
token = os.getenv('pk.eyJ1Ijoic2hhc2hhbmsxMjE5OTEiLCJhIjoiY2pocmdyaHloMmZlNTMwcWsxZTFyYmR5dyJ9.HFra3bHVqk-YxkJ0_eRKBA')

# %%
df_to_geojson(df, filename='points1.geojson',
              properties=['Altitude'], 
                     lat='Latitude', lon='Longitude', precision=3)
# Out:
# {'feature_count': 908, 'filename': 'points1.geojson', 'type': 'file'}

# %%
color_breaks = mapclassify.Natural_Breaks(df['Altitude'], k=8, initial=0).bins
color_stops = create_color_stops(color_breaks, colors='YlGnBu')

viz = CircleViz('points1.geojson',
                access_token=token, 
                height='400px',
                color_property = "Altitude",
                color_stops = color_stops,
                center = (39.985, 116.318),
                zoom = 7,
                below_layer = 'waterway-label')

viz.show()
# Out:
# <iframe id="map", srcdoc="<!DOCTYPE html>
# <html>
# <head>
# <title>mapboxgl-jupyter viz</title>
# <meta charset='UTF-8' />
# <meta name='viewport'
#       content='initial-scale=1,maximum-scale=1,user-scalable=no' />
# <script type='text/javascript'
#         src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.42.2/mapbox-gl.js'></script>
# <link type='text/css'
#       href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.42.2/mapbox-gl.css' rel='stylesheet' />
# <style type='text/css'>
#     body { margin:0; padding:0; }
#     .map { position:absolute; top:0; bottom:0; width:100%; }
#     .legend {
#         background-color: white;
#         color: black;
#         border-radius: 3px;
#         bottom: 50px;
#         width: 100px;
#         box-shadow: 0 1px 2px rgba(0, 0, 0, 0.10);
#         font: 12px/20px 'Helvetica Neue', Arial, Helvetica, sans-serif;
#         padding: 12px;
#         position: absolute;
#         right: 10px;
#         z-index: 1;
#     }
# ...

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-49-db2649dcf0a1> in <module>()
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from mpl_toolkits.basemap import Basemap
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'
